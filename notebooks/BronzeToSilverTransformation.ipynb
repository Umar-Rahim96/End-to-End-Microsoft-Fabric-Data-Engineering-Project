# %% [markdown]
# ## **PySpark Transformation**

# %% [markdown]
# ## **Data Reading**

# %%
df_customers = spark.read.format("parquet")\
                    .load("abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_customers_dataset.parquet")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 48, Finished, Available, Finished, False)

# %%
df_orderitems = spark.read.format("parquet")\
                       .load("abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_order_items_dataset.parquet")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 49, Finished, Available, Finished, False)

# %%
df_payments = spark.read.parquet("abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_order_payments_dataset.parquet")
# df now is a Spark DataFrame containing parquet data from "abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_order_payments_dataset.parquet".
display(df_payments)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 50, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 0f35d8d7-3d11-476a-9dc0-e7be91e8e12b)

# %%
df_reviews = spark.read.parquet("abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_order_reviews_dataset.parquet")
# df now is a Spark DataFrame containing parquet data from "abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_order_reviews_dataset.parquet".
display(df_reviews)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 51, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ddc982b8-05fb-4ac0-bd1a-db6d98ee8691)

# %%
df_products = spark.read.parquet("abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_products_dataset.parquet")
# df now is a Spark DataFrame containing parquet data from "abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_products_dataset.parquet".
display(df_products)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 52, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, da7cfcaf-9ead-4941-bec3-785d07f4002f)

# %%
df_orders = spark.read.parquet("abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_orders_dataset.parquet")
# df now is a Spark DataFrame containing parquet data from "abfss://DP700_DEV@onelake.dfs.fabric.microsoft.com/bronze_lakehouse.Lakehouse/Files/azure_raw_csv/olist_orders_dataset.parquet".
display(df_orders)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 53, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 5b60d2f2-8d4b-4e8e-b6f3-5f0d00f519ce)

# %%
display(df_customers.limit(5))
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 54, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 2baf43f9-3a3c-43bd-b7a1-f5b2f280e4fb)

# %% [markdown]
# #### **Data Transformation**

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 55, Finished, Available, Finished, False)

# %% [markdown]
# **SELECT**

# %%
df_customers = df_customers.select("customer_id","customer_unique_id","customer_zip_code_prefix")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 56, Finished, Available, Finished, False)

# %%
display(df_customers)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 57, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ed6a1ccd-2fe7-439c-8bab-a523404b3746)

# %% [markdown]
# **withColumnRenamed**

# %%
df_customers = df_customers.withColumnRenamed("customer_unique_id","unique_id")\
                            .withColumnRenamed("customer_zip_code_prefix","customer_zip_code")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 58, Finished, Available, Finished, False)

# %%
display(df_customers)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 59, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 73beb589-7167-4b0a-83cc-5a055c367e75)

# %% [markdown]
# **withcolumn TYPE CASTING**

# %%
df_customers = df_customers.withColumn(
    "customer_zip_code",
    col("customer_zip_code").cast(IntegerType())
)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 60, Finished, Available, Finished, False)

# %%
display(df_customers)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 61, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 4c2ba068-e962-4444-a728-cbbed311bf94)

# %%
df_customers.printSchema()
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 62, Finished, Available, Finished, False)
# root
#  |-- customer_id: string (nullable = true)
#  |-- unique_id: string (nullable = true)
#  |-- customer_zip_code: integer (nullable = true)

# %%
display(df_orderitems)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 63, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 54196e3b-8216-4c69-bf62-b99df63bb27e)

# %%
df_orderitems.printSchema()
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 64, Finished, Available, Finished, False)
# root
#  |-- order_id: string (nullable = true)
#  |-- order_item_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- shipping_limit_date: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- freight_value: string (nullable = true)

# %%
df_orderitems = df_orderitems.withColumn("shipping_limit_date",col("shipping_limit_date").cast(TimestampType()))
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 65, Finished, Available, Finished, False)

# %%
display(df_orderitems)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 66, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ab29f5e9-9945-4f93-8cac-4247fdb90cb5)

# %%
df_orderitems = df_orderitems.withColumn("price",col("price").cast(FloatType()))\
                               .withColumn("freight_value",col("freight_value").cast(FloatType()))
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 67, Finished, Available, Finished, False)

# %%
display(df_payments)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 68, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 9fab1ef1-eb70-4dd8-9cf9-2aec341b518d)

# %%
df_payments = df_payments.withColumn("payment_type",regexp_replace(col("payment_type"),"_"," "))\
                          .withColumn("payment_installment",col("payment_installments").cast(IntegerType()))\
                           .withColumn("payment_value",col("payment_value").cast(IntegerType()))
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 69, Finished, Available, Finished, False)

# %%
display(df_payments)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 70, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 25737d85-d2b5-4ec8-9615-60306cefd24f)

# %%
display(df_reviews)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 71, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6cbb3812-5461-4fd6-b3be-0c34bd59d8c8)

# %%
from pyspark.sql.functions import col, upper, lower

df_reviews = df_reviews.withColumn(
    "review_comment_title",
    upper(col("review_comment_title"))
).withColumn(
    "review_comment_message",
    lower(col("review_comment_message"))
)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 72, Finished, Available, Finished, False)

# %%
display(df_reviews)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 73, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 70a18723-ac78-492a-b1ce-dc677094b08e)

# %% [markdown]
# **Handling Nulls**

# %%
display(df_products)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 74, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 4fd5bacb-6fc0-48ef-ab3c-24bf683a9b37)

# %%
df_products = df_products.fillna({"product_category_name":"x","product_name_lenght":"y","product_photos_qty":"z"})
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 75, Finished, Available, Finished, False)

# %%
display(df_products)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 76, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 0aabecda-230f-4bb6-8bea-2c2f7c9adc6f)

# %%
df_products = df_products.withColumn(
    "product_weight_g",
    col("product_weight_g").cast(IntegerType())
).withColumn(
    "product_length_cm",
    col("product_length_cm").cast(IntegerType())
).withColumn(
    "product_height_cm",
    col("product_height_cm").cast(IntegerType())
)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 77, Finished, Available, Finished, False)

# %%
df_products.printSchema()
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 78, Finished, Available, Finished, False)
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = false)
#  |-- product_name_lenght: string (nullable = false)
#  |-- product_description_lenght: string (nullable = true)
#  |-- product_photos_qty: string (nullable = false)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: string (nullable = true)

# %%
df_products = df_products.withColumn("300flag",when(col("product_weight_g")>300,"Y").otherwise("N"))
display(df_products)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 79, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 18692fee-392e-460e-8216-71630ab6a767)

# %%
df_orders = df_orders.dropna(subset= ["order_delivered_carrier_date","order_delivered_customer_date"])
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 80, Finished, Available, Finished, False)

# %%
display(df_orders)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 81, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 2c0a80d8-3ec7-4c92-9286-305fde7c8d61)

# %%
df_orders = df_orders.withColumn("order_purchase_timestamp",col("order_purchase_timestamp").cast(TimestampType()))
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 82, Finished, Available, Finished, False)

# %% [markdown]
# **SPARK SQL**

# %%
df_orders.createOrReplaceTempView("order_temp_view")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 83, Finished, Available, Finished, False)

# %%
spark.sql("Select * from order_temp_view")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 84, Finished, Available, Finished, False)
# DataFrame[order_id: string, customer_id: string, order_status: string, order_purchase_timestamp: timestamp, order_approved_at: string, order_delivered_carrier_date: string, order_delivered_customer_date: string, order_estimated_delivery_date: string]

# %%
# %%sql
# select * from order_temp_view
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 85, Finished, Available, Finished, False)
# <Spark SQL result set with 1000 rows and 8 fields>

# %%
df_sql = spark.sql("""SELECT *,
        row_number() over(order by order_id)as row_number
        FROM
        order_temp_view""")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 86, Finished, Available, Finished, False)

# %%
display(df_sql)
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 87, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1fe6f414-a944-49bf-94be-00f0206743e2)

# %% [markdown]
# **Data Writing Scenarios**

# %%
df_sql.write.format("csv")\
             .mode("append")\
             .saveAsTable("bronze_lakehouse.csv_man_tbl")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 88, Finished, Available, Finished, False)

# %%
df_sql.write.format("delta")\
             .mode("append")\
             .option("path","Files/my_data")\
             .saveAsTable("ext_table_delta")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 89, Finished, Available, Finished, False)

# %% [markdown]
# **DATA WRITING**

# %%
df_customers.write.format("delta")\
            .mode("append")\
            .saveAsTable("Silver_Lakehouse.customers_enr")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 90, Finished, Available, Finished, False)

# %%
df_reviews.write.format("delta")\
            .mode("append")\
            .saveAsTable("Silver_Lakehouse.enr_reviews")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 91, Finished, Available, Finished, False)

# %%
df_payments.write.format("delta")\
            .mode("append")\
            .saveAsTable("Silver_Lakehouse.enr_payments")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 92, Finished, Available, Finished, False)

# %%
df_products.write.format("delta")\
            .mode("append")\
            .saveAsTable("Silver_Lakehouse.enr_products")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 96, Finished, Available, Finished, False)

# %%
df_orderitems.write.format("delta")\
            .mode("append")\
            .saveAsTable("Silver_Lakehouse.enr_orderitems")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 94, Finished, Available, Finished, False)

# %%
df_orders.write.format("delta")\
          .mode("append")\
          .saveAsTable("Silver_Lakehouse.enr_orders")
# Out:
# StatementMeta(, 55880763-ecb3-4400-8177-9b5e0f328134, 95, Finished, Available, Finished, False)
